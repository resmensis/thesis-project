# %% [markdown]
# import pandas as pd
#
#
#
# d = {
#     "permno": [1, 1, 2, 2, 1, 2],
#     "date": pd.to_datetime([
#         "1990-01", "1990-03", "1990-02",
#         "1990-01", "1990-02", "1990-03"
#     ]).to_period("M"),
#     "col1": [1, 3, 2, 1, 2, 3],
#     "col2": [4, 6, 5, 4, 5, 6],
# }
#
# df = pd.DataFrame(data=d)
# print(df)
# print(df.dtypes)
# df = df.sort_values(["permno", "date"]).copy()
#
# df["col1"] = (
#     df.groupby("permno")["col1"]
#       .shift(-1)
# )
# df["col2"] = (
#     df.groupby("permno")["col2"]
#       .shift(-2)
# )
# df

# %%
import pandas as pd
import numpy as np
from transformers import GroupedMedianImputer

df = pd.DataFrame({
    "permno": [1, 2, 3, 4, 5],
    "year": [2020, 2020, 2020, 2021, 2021],
    "industry": ["A", "A", "B", "A", "B"],
    "bm": [0.4, np.nan, 0.8, np.nan, 1.0],
    "mom": [0.2, 0.4, np.nan, 0.6, np.nan],
})

imputer = GroupedMedianImputer(
    group_cols=["year", "industry"],
    value_cols=["bm", "mom"],
    fallback="global_median",
)

df_imputed = imputer.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[43], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from transformers import GroupedMedianImputer
#       5 df = pd.DataFrame({
#       6     "permno": [1, 2, 3, 4, 5],
#       7     "year": [2020, 2020, 2020, 2021, 2021],
#    (...)
#      10     "mom": [0.2, 0.4, np.nan, 0.6, np.nan],
#      11 })
#      13 imputer = GroupedMedianImputer(
#      14     group_cols=["year", "industry"],
#      15     value_cols=["bm", "mom"],
#      16     fallback="global_median",
#      17 )
#
# ImportError: cannot import name 'GroupedMedianImputer' from 'transformers' (c:\Coding\thesis-project\transformers.py)
